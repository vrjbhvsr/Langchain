# %% [markdown]
# # 📘 Topic: Deep dive into Langchain- Chains and Runnables
#
#
#
# ## 🎯 Objective
# ###  Understanding concept of Chains and Runnables
#
# ### 🔶 What is Chains?
#
# * Chains are components that connect different parts of a workflow together. For example, in the previous files, when I created a prompt, I had to manually call `prompt = template.invoke()` and then pass it to `model.invoke(prompt)`. Chains allow us to link these steps together seamlessly, so the output of one component automatically becomes the input to the next — without having to handle each step separately.
#
# * It works as a pipeline, where it first works as output of first step becomes the input of second step.
#
# * We

# %%
from langchain_core.runnables import RunnableParallel, RunnableBranch, RunnableLambda
